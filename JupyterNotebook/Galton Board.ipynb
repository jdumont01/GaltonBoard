# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Galton-Board-Project" data-toc-modified-id="Galton-Board-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Galton Board Project</a></span><ul class="toc-item"><li><span><a href="#Marked-Up-Concept-with-Legos" data-toc-modified-id="Marked-Up-Concept-with-Legos-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Marked Up Concept with Legos</a></span></li><li><span><a href="#Galton-Board-Simulator-in-Action" data-toc-modified-id="Galton-Board-Simulator-in-Action-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Galton Board Simulator in Action</a></span></li><li><span><a href="#Objective" data-toc-modified-id="Objective-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Objective</a></span></li></ul></li><li><span><a href="#Agile-Approach" data-toc-modified-id="Agile-Approach-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Agile Approach</a></span><ul class="toc-item"><li><span><a href="#User-Stories-And-Acceptance-Criteria" data-toc-modified-id="User-Stories-And-Acceptance-Criteria-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>User Stories And Acceptance Criteria</a></span><ul class="toc-item"><li><span><a href="#User-Interface" data-toc-modified-id="User-Interface-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>User Interface</a></span></li><li><span><a href="#Historical-Results" data-toc-modified-id="Historical-Results-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Historical Results</a></span></li><li><span><a href="#Installing-the-Simulator" data-toc-modified-id="Installing-the-Simulator-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Installing the Simulator</a></span></li><li><span><a href="#Test-Cases-for-the-Simulator" data-toc-modified-id="Test-Cases-for-the-Simulator-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Test Cases for the Simulator</a></span></li></ul></li><li><span><a href="#Defining-Minimal-Viable-Product-(MVP)" data-toc-modified-id="Defining-Minimal-Viable-Product-(MVP)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Defining Minimal Viable Product (MVP)</a></span><ul class="toc-item"><li><span><a href="#MVP-Criteria-(First-Set-of-Deliverables)" data-toc-modified-id="MVP-Criteria-(First-Set-of-Deliverables)-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>MVP Criteria (First Set of Deliverables)</a></span></li><li><span><a href="#Second-Set-of-Deliverables" data-toc-modified-id="Second-Set-of-Deliverables-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Second Set of Deliverables</a></span></li><li><span><a href="#Third-Set-of-Deliverables" data-toc-modified-id="Third-Set-of-Deliverables-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Third Set of Deliverables</a></span></li><li><span><a href="#Fourth-Set-of-Deliverables" data-toc-modified-id="Fourth-Set-of-Deliverables-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Fourth Set of Deliverables</a></span></li><li><span><a href="#Fifth-Set-of-Deliverables" data-toc-modified-id="Fifth-Set-of-Deliverables-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Fifth Set of Deliverables</a></span></li></ul></li><li><span><a href="#Scrum-Board-Updates" data-toc-modified-id="Scrum-Board-Updates-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Scrum Board Updates</a></span></li><li><span><a href="#Processing-User-Feedback" data-toc-modified-id="Processing-User-Feedback-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Processing User Feedback</a></span><ul class="toc-item"><li><span><a href="#Feedback-from-MVP-Demo" data-toc-modified-id="Feedback-from-MVP-Demo-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Feedback from MVP Demo</a></span></li><li><span><a href="#Processing-and-Scheduling-User-Feedback-Enhancements" data-toc-modified-id="Processing-and-Scheduling-User-Feedback-Enhancements-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Processing and Scheduling User Feedback Enhancements</a></span></li><li><span><a href="#Updated-Sprint-Board" data-toc-modified-id="Updated-Sprint-Board-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Updated Sprint Board</a></span></li></ul></li></ul></li><li><span><a href="#Using-the-Galton-Board-Simulator" data-toc-modified-id="Using-the-Galton-Board-Simulator-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Using the Galton Board Simulator</a></span><ul class="toc-item"><li><span><a href="#Starting-the-Simulator" data-toc-modified-id="Starting-the-Simulator-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Starting the Simulator</a></span></li><li><span><a href="#The-Main-Board" data-toc-modified-id="The-Main-Board-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>The Main Board</a></span><ul class="toc-item"><li><span><a href="#Board-Configuration" data-toc-modified-id="Board-Configuration-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Board Configuration</a></span></li><li><span><a href="#Current-State-of-the-Ball's-Path" data-toc-modified-id="Current-State-of-the-Ball's-Path-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Current State of the Ball's Path</a></span></li><li><span><a href="#Animation-Section" data-toc-modified-id="Animation-Section-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Animation Section</a></span></li><li><span><a href="#Bucket-Data" data-toc-modified-id="Bucket-Data-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Bucket Data</a></span></li><li><span><a href="#The-Menu" data-toc-modified-id="The-Menu-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>The Menu</a></span><ul class="toc-item"><li><span><a href="#The-Board-Option" data-toc-modified-id="The-Board-Option-3.2.5.1"><span class="toc-item-num">3.2.5.1&nbsp;&nbsp;</span>The Board Option</a></span></li><li><span><a href="#Statistics-Window" data-toc-modified-id="Statistics-Window-3.2.5.2"><span class="toc-item-num">3.2.5.2&nbsp;&nbsp;</span>Statistics Window</a></span></li><li><span><a href="#Help" data-toc-modified-id="Help-3.2.5.3"><span class="toc-item-num">3.2.5.3&nbsp;&nbsp;</span>Help</a></span></li><li><span><a href="#Getting-Started" data-toc-modified-id="Getting-Started-3.2.5.4"><span class="toc-item-num">3.2.5.4&nbsp;&nbsp;</span>Getting Started</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>References</a></span><ul class="toc-item"><li><span><a href="#Reference-1---The-Binomial,-Poisson,-and-Gaussian-Distributions" data-toc-modified-id="Reference-1---The-Binomial,-Poisson,-and-Gaussian-Distributions-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Reference 1 - The Binomial, Poisson, and Gaussian Distributions</a></span><ul class="toc-item"><li><span><a href="#Binomial-Distribution" data-toc-modified-id="Binomial-Distribution-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Binomial Distribution</a></span><ul class="toc-item"><li><span><a href="#Why-is-it-Important?" data-toc-modified-id="Why-is-it-Important?-4.1.1.1"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>Why is it Important?</a></span></li><li><span><a href="#Example" data-toc-modified-id="Example-4.1.1.2"><span class="toc-item-num">4.1.1.2&nbsp;&nbsp;</span>Example</a></span></li><li><span><a href="#Derive-the-Mean-and-the-Variance" data-toc-modified-id="Derive-the-Mean-and-the-Variance-4.1.1.3"><span class="toc-item-num">4.1.1.3&nbsp;&nbsp;</span>Derive the Mean and the Variance</a></span></li></ul></li><li><span><a href="#Poisson-Distribution" data-toc-modified-id="Poisson-Distribution-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Poisson Distribution</a></span></li><li><span><a href="#Gaussian-Distribution" data-toc-modified-id="Gaussian-Distribution-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Gaussian Distribution</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Galton Board Project

# %% [markdown]
# One of my favorite math tools is the Galton Board as it is a great tool to see basic statistics in action.  It can be used as a guessing game, and as a tool to understand the relationship among the Binomial distribution, the Poisson distribution, and the Gaussian distribution.
#
# This project is something I decided to do on a whim in December 2021 because I have wanted to write code to create a Galton Board simulator, but I never reserved the time.  A few years earlier, I built a Galton board with Lego and decided to create a Python-based simulator.
#
# In addition to writing Python code, I decided to use the Agile methodology to design, organize and roll out the simulation.  This was an opportunity to use my certified Agile Scrum Master skills on a project.
#
# The remainder of this Notebook describes the features of the simulator as well as references detailing the mathematics behind the Galton Board.

# %% [markdown]
# ## Marked Up Concept with Legos

# %% [markdown]
# While I watched a horrific first half of Super Bowl LI, I decided to channel my frustration toward something creative.  I  created a version of a Galton Board with Legos.  The following demonstrates how this incarnation of the Galton Board is used.

# %% [markdown]
# ## Galton Board Simulator in Action

# %% [markdown]
# This video demonstrates the Galton Board simulator in action.

# %% [markdown]
# ## Objective

# %% [markdown]
# The objective of this project is to create a Python-based Galton Board simulator using Agile methodology.

# %% [markdown]
# # Agile Approach

# %% [markdown]
# This project will be defined and developed via the Agile process:
# - Create User Stories with Acceptance Criteria
# - Assign points to each story
# - Order the stories based on priority to create MVP
# - Develop and Demonstrate the Deliverables for each Story

# %% [markdown]
# ## User Stories And Acceptance Criteria

# %% [markdown]
# The following sections provide a list of user-based stories grouped by common features:  UI, Results etc.  Each story includes a list of Acceptance Criteria defining the set of features and/or behavior necessary to satisfy the user story.  Then, the stories are prioritized in collections determining the Minimum Viable Product (MVP) as well as ensuring added value features.  Each set of deliverables are assigned to "sprints" and tracked via a spreadsheet throughout the development cycle until the story is Done.

# %% [markdown]
# ### User Interface

# %% [markdown]
# **Story 1:**  As a new user, I want to define the depth of the Galton Board, so that I can change the number of levels of the Galton Board.
#
# **Acceptance Criteria:**
# [ ] The user will have an option to define the depth of the Galton Board.
#
# **Story 2:**  As a new user, I want to define the number of times the Galton Board is traversed, so that I can analyze how the final distribution of results changes with the number of traversals.
#
# **Acceptance Criteria:**
# [ ] The user will have an option to define the number of times the Galton Board is traversed - called events.
# [ ] The user will have an option to define how quickly each level of the Galton Board is reached - called rate.
#
# **Story 3:**  As a new user, I want to view an extensive set of results, so that I can view the distribution of the each completed event.
#
# **Acceptance Criteria:**
# [ ] The results will be tallied in real-time, after each event completes.
# [ ] The accumulated number of times an event results in each bucket will be displayed for the user.
# [ ] The fraction of each accumulated bucket divided by the total number of events will be displayed for the user.
# [ ] The expected fraction of each bucket will be calculated and displayed for the user.
# [ ] The traversed pathway from each event will be displayed for the user.
#
# **Story 4:**  As a new user, I want to select large values for the depth of the Galton Board and a large number of events, so that I can create and analyze complex distributions with or without a UI.
#
# **Acceptance Criteria:**
# [ ] The user will be able to define board depths of up to 100.
# [ ] The user will be able to define the total number of events to process up to 1 billion.
# [ ] The user will be able to view raw stats in the UI.
#
# **Story 5:**  As a user interested in statistics, I want to overlay different common distributions, so that I can compare the results generated by the Galton Board to common distributions like:
#
# * Student T-distribution
# * Poisson distribution
# * Normal distribution
#
# **Acceptance Criteria:**
# [ ] The user will have the ability to select different "common" distributions.
# [ ] The user will see an overlay of the distribution and the results of the Galton Board events in a histogram.
#
# **Story 6:**  As a user interested in studying statistical bias, I want to be able to define a rotational angle, so that the events can be skewed either to the left or the right.
#
# **Acceptance Criteria:**
# [ ] The user will have the ability to select an angle that rotates the board.
# [ ] The board will be displayed with the rotation.
#
# **Story 7:**  As a user who does not want to use a keyboard, I want to be able to use speech recognition to dictate the input and receive the results of each run, so that I can focus on other tasks while the simulator is running.
#
# **Acceptance Criteria:**
# [ ] The user will have the ability to select dictate the configuration parameters to setup a simulation.
# [ ] The results of the simulation will be presented via voice.

# %% [markdown]
# ### Historical Results

# %% [markdown]
# **Story 8:**  As a user interested in comparing long-term result sets, I want the results of each run to be saved, so that I can recall the results.
#
# **Acceptance Criteria:**
# [ ] The user will have access to the raw data to query.
# [ ] The data will be saved so that each run is uniquely identified.

# %% [markdown]
# ### Installing the Simulator

# %% [markdown]
# **Story 9:**  As a user interested in deploying the simulator to different environments, I want the final set of code to be portable and installable, so that I can install the simulator along with all of the code dependencies on any system.
#
# **Acceptance Criteria:**
# [ ] The user will have access to the package via GitHub.
# [ ] The user will be able to install the package on Windows and Linux systems.
# [ ] The user will be able to run the product without issue post installation

# %% [markdown]
# ### Test Cases for the Simulator

# %% [markdown]
# **Story 10:**  As a user interested in deploying the simulator, I want to have a series of installation test scripts, so that I can verify the installation was successful.
#
# **Acceptance Criteria:**
# [ ] The user will have access to the package via GitHub.
# [ ] The user will have access to the test scripts to execute.

# %% [markdown]
# ## Defining Minimal Viable Product (MVP)

# %% [markdown]
# There are several stories to review and implement; however, to deliver a minimal viable product (MVP), a first set of deliverables has to be selected.

# %% [markdown]
# ### MVP Criteria (First Set of Deliverables)

# %% [markdown]
# The MVP will be based on the highest value work.  First, the since basic product needs to work the following features need to be implemented:
# - how the Galton Board will look based on user input.
# - how many times it will be traversed based on user input.
# - how the output of the results will be presented to the user.

# %% [markdown]
# ### Second Set of Deliverables

# %% [markdown]
# The second set of deliverables will allow the user to perform statistical comparisons.  This includes the following features:
# - overlaying a user-defined distribution on the results.
# - retrieving historical data

# %% [markdown]
# ### Third Set of Deliverables

# %% [markdown]
# The third set of deliverables will allow the user to:
# - query historical data
# - install the simulator in Windows environments
# - run installation tests to verify the package works as expected

# %% [markdown]
# ### Fourth Set of Deliverables

# %% [markdown]
# The fourth set of deliverables will include speech recognition for the user to dictate the configuration parameters and receive the results via voice.

# %% [markdown]
# ### Fifth Set of Deliverables

# %% [markdown]
# The fifth set of deliverables will be based on different ways to use a Galton Board to peform statistical bias run by rotating the Galton Board.

# %% [markdown]
# ## Scrum Board Updates

# %% [markdown]
# A Scrum board is created for each group of deliverables defined earlier.  The stories comprising the deliverables are tracked in 4 phases:
# - To Do - The high level functional portion of the story that needs to be scheduled.
# - In Progress - The functional portion of the story that is currently being worked on (i.e. coding)
# - To Verify - The functional portion of the story being validated against the Acceptance Criteria
# - Done - The functional portion of the story is ready for use.
#
# As sample Scrum Board for this project is shown below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Processing User Feedback

# %% [markdown]
# When a feature is ready to for a user to review, the feedback is tracked using a relative scale of importance and added into a sprint for development.

# %% [markdown]
# ### Feedback from MVP Demo

# %% [markdown]
# The following feedback was provided by 2 users during a demo of the MVP.  The two screenshots below can be used as references for the following comments:
# 1. The Galton Board results are hard to read if the board depth is greater than 10.
# 2. The user should be able to choose the color of the ball and the pegs.
# 3. The user should be able to allow multiple balls in play, so that the simulation can complete faster.
# 4. The user needs to view directions to use the simulator.
# 5. The user should be able to hover over a bucket and see the accumulated value and the expected value in real-time.
# 6. The results screen should use histograms to display the results.
# 7. The Galton Board Results UI should not appear again when it is closed by the user.  That is, the user should only see the Galton Board Results UI when prompted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Processing and Scheduling User Feedback Enhancements

# %% [markdown]
# The 7 feedback points were reviewed and the results are listed here.
#
# *1. The Galton Board results are hard to read if the board depth is greater than 10.*
#
# There will be 2 stories that will be created:
#
# **Story 1a:  As a user, I need the board depth to have a maximum of 10 rows, so that I can view the raw data in the UI easily.**
#
# **Story 1b:  As a user who wants to analyze a simulation requiring more than 10 rows, I need a solution that can simply generate the results without the animation, so that the results can be generated faster.**
#
# Story 1a was incorporated into sprint 1 and completed.  Story 1b will be placed in the backlog to be added to a sprint later.
#
# *2. The user should be able to choose the color of the ball and the pegs.*
#
# A new story will be created and added to the backlog:
#
# **Story 2a:  As a user who wants to customize the board components, I need to define the color of the ball and the color of the pegs as well as save the board configuration, so that I personalize the board.**
#
# This story will be placed in the backlog and introduced in a later sprint.
#
# *3. The user should be able to allow multiple balls in play, so that the simulation can complete faster.*
#
# A new story will be created and added to the backlog:
#
# **Story 3a:  As a user who wants to run several simulations, I need to have multiple balls released and in play, so that the simulation can complete faster.**
#
# This story will be placed in the backlog and introduced in a later sprint.
#
# *4. The user needs to view directions to use the simulator.*
#
# A new story will be created and added to the backlog:
#
# **Story 4a:  As a new user, I need online usage instructions, so that I can easily understand how to start a simulation and how to generate results.**
#
# This story was added back to the first sprint, and completed.
#
# *5. The user should be able to hover over a bucket and see the accumulated value and the expected value in real-time.*
#
# **Will Not Do:**  This story is already covered and the functionality exists in the UI to view the real-time accumulated statistics and the expected values for each bucket.
#
# *6. The results screen should use histograms to display the results.*
#
# A new story will be created and added to the backlog:
#
# **Story 6a:  As a user, I want the option to either overlay the statistics output with a histogram or display the results as a histogram alone, so that I have options to export the graphical results.**
#
# *7. The Galton Board Results UI should not appear again when it is closed by the user.  That is, the user should only see the Galton Board Results UI when prompted.*
#
# This is a "bug" as the statistics UI should clear itself.  This bug will be resolved in sprint 2.

# %% [markdown]
# ### Updated Sprint Board

# %% [markdown]
# The new sprint 1 board is updated from earlier.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Using the Galton Board Simulator

# %% [markdown]
# This section covers how to use the Galton Board simulator.

# %% [markdown]
# ## Starting the Simulator

# %% [markdown]
# The Galton Board simulator is started by entering the following command:
#
# python ./GaltonBoard.py
#
# The initial Galton Board screen will appear.

# %% [markdown]
# ## The Main Board

# %% [markdown]
# The main screen is used to define the user input and basic output including the ball in motion.  PyQt5 was used to generate the UI.  The graph screen is also generated via the PyQt5 library and matplotlib Python module and the MplCanvas in the matplotlib.backends.backend_qt5agg module.  These programming tools can be installed via python pip.
#
# Reference:  https://python.hotexamples.com/examples/mplwidget/-/mplCanvas/python-mplcanvas-function-examples.html
#
#
# The following board graphic is a simulation in which 1000 balls will traverse a board depth of 7 (8 buckets).  The time between events is 1 ms.  An event includes releasing a ball, moving the ball 1 spot, and completing the board to update the accumulated statistics.
#
# Note that the simulation was paused as the active ball is just reaching the third level of pegs. You can see that the first two levels were completed from the data in the first line that updates the ball's path; [L, R] means that the ball went left at the first level and then right at the second level.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# The board has 4 sections:
# - The board configuration
# - The current state of the ball's path
# - The animation of the ball as it traverses the board
# - The accumulated and expected number of events for each bucket.

# %% [markdown]
# ### Board Configuration

# %% [markdown]
# The board configuration parameters entered by the user are displayed on the second line of the board UI:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Current State of the Ball's Path

# %% [markdown]
# The path of each ball is tracked in real time after the ball moves from one level to the next level below it.  The length of this list will be as long at the board depth.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Animation Section

# %% [markdown]
# In this section the user will observe the ball in motion from the time at which it is released until it reaches a bucket.  The event timer is user to trigger the simulator to:
#
# 1. release the ball
#
# 2. move the ball 1 block in any direction
#
# 3. update the accumulated bucket values
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bucket Data

# %% [markdown]
# This section is at the bottom of the UI.  There are two lines of data:
#
# 1.  Accumulated events (i.e. the number of times a ball reached a bucket)
#
# 2.  Expected number of events
#
# The accumulated data line is displayed in white buckets and is updated each time a ball reaches one of the buckets.
#
# ![image-2.png](attachment:image-2.png)
#
#
# The expected number of events line is a series of green boxes that are calculated when the board is created.
#
# ![image.png](attachment:image.png)
#
# The number displayed is the approximate number of balls (N), the index of each bucket (k) and the board depth (n) that should reach the bucket based on
#
# \begin{equation}
# \begin{split}
# P = \frac{n!}{k! \cdot (n - k)!} \cdot (\frac{1}{2} )^n \cdot N
# \end{split}
# \label{eq:ExpBucket} \tag{3-1}
# \end{equation}
#
# Since this is calculated for each bucket, $k | k \in {0, 1, \cdots, n}$
#
# Occasionally, the sum of these values will NOT be equal to the total number of balls defined by the user.  This is due to round off errors during the calculation.

# %% [markdown]
# ### The Menu

# %% [markdown]
# There are 4 main menu options:
# Board
# Statistics
# Help
# Getting Started
# ![image.png](attachment:image.png)

# %% [markdown]
# #### The Board Option

# %% [markdown]
# The Board Option allows the user to Start, Stop, Pause and Resume a simulation.

# %% [markdown]
# ##### Start Option

# %% [markdown]
# The Start option initiates the simulation.  The hot key is Ctrl-S.  Upon starting a simulation, the user will enter the:
#
# - Board Depth (default:  7, minimum = 2, maximum = 10)
#
# ![image.png](attachment:image.png)
#
# - Number of Balls (default:  100, minimum = 1, maximum = 1000000000 (1 billion) )
#
# ![image-2.png](attachment:image-2.png)
#
#
# - Event Timer (ms) (default: 100 ms, minimum = 0, maximum = 200 ms).  A value of 0 will direct the simulator to go as fast as possible)
#
# ![image-3.png](attachment:image-3.png)
#
# Each dialog box will show the default value in the user entry field as well as the minimum and maximum allowed values.  Upon selecting the Ok button, the UI will verify the user input by comparing the input value to the minimum and maximum values allowed for a parameter.  If the input is outside of the allowed values, the user will be required to enter the value again.

# %% [markdown]
# The board will immediately start the simulation.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #####  Stop Option

# %% [markdown]
# The stop option will halt the simulation.  In a future version, the simulation will write out to a file to save the state of the board and the accumulated statistics.  The user can Resume the simulation by selecting the Resume option.  The hot key is Ctrl-T.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Reset Option

# %% [markdown]
# The reset option resets the statistics while the simulation is active.  The Hot Key is Ctrl-R.
#
# Before reset
# ![image.png](attachment:image.png)
#
# After reset (and a few ensuing events)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Pause Option

# %% [markdown]
# The pause option will immediately pause the simulation.  The user can resume, or quit.  The hot key is Ctrl-P
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Resume Option

# %% [markdown]
# The Resume option allows the user to resume the simulator from the point at which it was paused.  The hot key is Ctrl-E.
#
# Simulation Paused
# ![image.png](attachment:image.png)
#
# Simulated Resumed
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Exit Option

# %% [markdown]
# The Exit option stops the simulation and exits the UI.  The hot key is Ctrl-X.

# %% [markdown]
# #### Statistics Window

# %% [markdown]
# The Statistics window is separate so that the accumulated events can be viewed as a plot of event frequency for each bucket over time.  The idea to plot this separately is to show the user, that for many events the binomial distribution will converge to the Normal (or Gaussian) distribution.  The Statistics window will refresh every 5 seconds by default.
#
# The hot key is Ctrl-U.
#
# ![image.png](attachment:image.png)
#
# The user can hover over the plot and the UI will return the coordinates (bucket, frequency).  In the following diagram, the user is hovering over (5, 113) which represents the number of events that have ended at bucket 5 (= 113 events).
#
# ![image-2.png](attachment:image-2.png)
#
# The window can be closed using the X in the upper-right corner of the UI.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Help

# %% [markdown]
# The Help screen displays an About box describing the version of the software.  The hot key is Ctrl-H and the About window is Ctrl-A.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Getting Started

# %% [markdown]
# The Getting Started option will display a basic set of instructions describing how to user the Galton Board UI.  The hot key is Ctrl-G.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # References

# %% [markdown]
# ## Reference 1 - The Binomial, Poisson, and Gaussian Distributions

# %% [markdown]
# The purpose of this page, is to derive the Normal Distribution from the Binomial Distribution as a reference for the Galton Board project.  For the purposes of predicting the probability of a ball reaching a certain bucket, the Binomial distribution will be used.  The derivation of the Poisson and the Guassian distributions has been added for fun.

# %% [markdown]
# ### Binomial Distribution

# %% [markdown]
# One question that gets asked when observing the results of a Galton Board is, given a number of balls to be dropped into the Galton Board, how can we predict the number of balls in any of the buckets?  And what is the probability of the next ball reaching a specific bucket.  This section answers these questions.

# %% [markdown]
# #### Why is it Important?

# %% [markdown]
# The Binomial distribution is a fundamental way to calculate the probability of a path, k, in a tree of $2^{\text{board depth}}$ possible results.  There may be, as we saw in the Galton Board, several ways to traverse the board to get a point that is between boundaries.  For example, with a board that is 4 levels deep, there are 5 ending points (or buckets).  To end up in either the first or the last bucket, only one path can be traversed.  For the second and the fourth buckets, there are 4 possible paths and for the middle bucket there are 6 possible paths.
#
# |Bucket Number|Possible Paths|Number of Paths|
# | :-: | :-: | :-: |
# |1|LLLL|1|
# |2|RLLL, LRLL, LLRL, LLLR|4|
# |3|RRLL, RLRL, RLLR, LRRL, LRLR, LLRR|6|
# |4|LRRR, RLRR, RRLR, RRRL|4|
# |5|RRRR|1|
#
# The total number of possible paths is 1 + 4 + 6 + 4 + 1 = 16 = $2^4$.  The probability of reaching any bucket is the number of possible paths to get to that bucket divided by the total number of possible paths.  The following table includes the probability of reaching the final state of any bucket.
#
# |Bucket Number|Possible Paths|Number of Paths|Probability|
# | :-: | :-: | :-: | :-:|
# |1|LLLL|1|1/16 = 0.0625|
# |2|RLLL, LRLL, LLRL, LLLR|4|4/16 = 0.25|
# |3|RRLL, RLRL, RLLR, LRRL, LRLR, LLRR|6|6/16 = 0.375|
# |4|LRRR, RLRR, RRLR, RRRL|4|4/16 = 0.25|
# |5|RRRR|1|1/16 = 0.0625|
#
# Note that the sum of the probabilities has to be 1, otherwise there are paths that have not been accounted for.  In this example, the sum of the probabilities: 0.0625 + 0.25 + 0.375 + 0.25 + 0.0625 = 1.
#
# Picture a Galton Board configuration in which the depth is 100.  To perform the same manual analysis on this board to list all of the possible paths to get to a single bucket would take a long time.  There are a total of $2^{100} = 1.267 \cdot 10^{30}$ possibilities.  Good luck with that without writing a program!
#
# So how can we determine the number of possible paths to get to a bucket (endpoint) for any given board of depth d?  The answer lies in the Binomial Distribution.
#
# Let's start by asking how many ways can we get to a bucket?  That is answered using combinatorics.  Specifically, if we have n steps, the number of possible ways we can get to the k-th bucket is
# \begin{equation}
# \begin{split}
# \frac{n!}{k! \cdot (n - k)!}
# \end{split}
# \label{eq:binomial1_1} \tag{1-1}
# \end{equation}
#
# Referring to the example above for a board of depth 4, we can calculate the number of paths to each bucket.  Note that $k \leq n$.
#
# |Bucket Number (0 index)|Possible Paths|Number of Paths|
# | :-: | :-: | :-: |
# |0|LLLL|$\frac{4!}{0! \cdot (4 - 0)!} = \frac{4!}{4!}$ = 1|
# |1|RLLL, LRLL, LLRL, LLLR|$\frac{4!}{1! \cdot (4 - 1)!} = \frac{4!}{3!}$ = 4|
# |2|RRLL, RLRL, RLLR, LRRL, LRLR, LLRR|$\frac{4!}{2! \cdot (4 - 2)!} = \frac{4!}{2 \cdot 2}$ = 6|
# |3|LRRR, RLRR, RRLR, RRRL|$\frac{4!}{3! \cdot (4 - 3)!} = \frac{4!}{3!}$ = 4|
# |4|RRRR|$\frac{4!}{4! \cdot (4 - 4)!} = \frac{4!}{4!}$ = 1|
#
# Now the we know how to calculate the number of ways to reach an endpoint k, given a path of n steps, the next step is to determine how to calculate the probability of reaching endpoint k.
#
# This is where the Binomial Distribution takes center stage.  It states that given the number of possible paths to get to an endpoint, the probability of reaching that endpoint k is
#
# \begin{equation}
# \begin{split}
# P = \binom{n}{k} \cdot p^k \cdot (1 - p)^{n-k}
# \end{split}
# \label{eq:binomial1_2} \tag{1-2}
# \end{equation}
#
# For the Galton board, p = 1/2 because there is an equal chance of the ball going left or right.  Therefore,
# \begin{equation}
# \begin{split}
# P &= \binom{n}{k} \cdot p^k \cdot (1 - p)^{n-k} \\
# &= \binom{n}{k} \cdot (\frac{1}{2} )^k \cdot (1 - \frac{1}{2} )^{n-k} \\
# &= \binom{n}{k} \cdot (\frac{1}{2} )^k \cdot (\frac{1}{2} )^{n-k} \\
# &= \binom{n}{k} \cdot (\frac{1}{2} )^n \\
# &= \frac{n!}{k! \cdot (n - k)!} \cdot (\frac{1}{2} )^n
# \end{split}
# \label{eq:binomial1-3} \tag{1-3}
# \end{equation}
#
# Now the probabilities can be added to the table:
#
# |Bucket Number (0 index)|Possible Paths|Number of Paths|Probability (#Paths x $\cdot (\frac{1}{2})^n$) |
# | :-: | :-: | :-: | :-: |
# |0|LLLL|$\frac{4!}{0! \cdot (4 - 0)!} = \frac{4!}{4!}$ = 1| $1 \cdot (\frac{1}{2})^4 $ = 1/16 = 0.0625|
# |1|RLLL, LRLL, LLRL, LLLR|$\frac{4!}{1! \cdot (4 - 1)!} = \frac{4!}{3!}$ = 4| $4 \cdot (\frac{1}{2})^4 $ = 4/16 = 0.25|
# |2|RRLL, RLRL, RLLR, LRRL, LRLR, LLRR|$\frac{4!}{2! \cdot (4 - 2)!} = \frac{4!}{2 \cdot 2}$ = 6| $6 \cdot (\frac{1}{2})^4 $ = 6/16 = 0.375|
# |3|LRRR, RLRR, RRLR, RRRL|$\frac{4!}{3! \cdot (4 - 3)!} = \frac{4!}{3!}$ = 4| $4 \cdot (\frac{1}{2})^4 $ = 4/16 = 0.25|
# |4|RRRR|$\frac{4!}{4! \cdot (4 - 4)!} = \frac{4!}{4!}$ = 1| $1 \cdot (\frac{1}{2})^4 $ = 1/16 = 0.0625|
#
# Now we have a way to calculate the number of paths that can be traversed in a Galton Board, to reach a specific endpoint or bucket.

# %% [markdown]
# #### Example

# %% [markdown]
# The following code calculates each Binomial coefficient for any board depth, and then plots the data.  Note how the shape of the plot changes when the board depth approaches of 10.  The board depth is defined in the code entry point (line 118).

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

SMALL_BOARD_DEPTH = 10

def binomialCoefficient(n: int, k: int):
    """Ensure n and k and the return value are integers"""
    nFactorial = math.factorial(n)
    kFactorial = math.factorial(k)
    diffFactorial = math.factorial(n - k)
    
    return int(nFactorial/(kFactorial * diffFactorial))

def probabilityForBucket(c: int, t: int):
    """Calculate the probability of reaching each endpoint."""
    return float(c/t)

def addLabelValues(buckets, values):
    """Add the y value to a bar."""
    for i in range(len(buckets)):
        plt.text(i,values[i],values[i], ha = 'center',
                 bbox = dict(facecolor = 'red', alpha =0.8))    
    
    return    
 
def plotResults(dataDict):
    """Plot a bar graph of the results"""
    buckets = list(dataDict.keys())
    values = list(dataDict.values())
    nBuckets = len(buckets)
    
    fig = plt.figure(figsize = (15, 5))    
    plt.bar(buckets, values, color = 'blue', width = 0.5)
    
    plt.xlabel("Bucket Number")
    plt.xticks(buckets)
    plt.ylabel("Number of Paths to Bucket\n(aka Binomial Coefficient)")
    plt.title(f'Histogram of Expected Paths For Board Depth {nBuckets - 1:d}')
    
    # The plot looks messy if the y-values are printed for large boards.
    if len(buckets) <= SMALL_BOARD_DEPTH + 1:
        addLabelValues(buckets, values)
    plt.show()
    
    return

def printHeader(boardDepth : int , totalPaths : int ):
    """boardDepth (int), totalPaths (int)
        Print a common header for tabular output.
    """        
    print (f'**** Galton Board Output for Depth {boardDepth} ****')
    if boardDepth <= SMALL_BOARD_DEPTH:
        print (f'**** Possible Paths {totalPaths:d} ')
    else:
        print (f'**** Possible Paths {totalPaths:2.6e} ')

    return

def printData( boardDepth : int , totalPaths : int, bucket : int, coeff : int, prob : float ):
    """boardDepth (int), totalPaths (int), bucket (int), coeff (int), prob (float)
        prints the data in csv format
    """       
    # special formatting based on the expected size of the numbers
    if boardDepth <= SMALL_BOARD_DEPTH:
        print (f'{bucket:6d},{coeff:15d},{coeff:10d}/{totalPaths:d},{prob:4.6f}')
    else:
        print (f'{bucket:6d},{coeff:2.5e},{coeff :2.5e}/{totalPaths:2.5e},{prob:2.5e}')
    
    return
    
def generateData(boardDepth : int , totalPaths : int ):
    """boardDepth (int), totalPaths (int)
        return a list of data
    """
    data = []

    printHeader(boardDepth, totalPaths)    
    
    print (f'Bucket, Possible Paths, Probability Frac, Probability')
    for bucket in range(boardDepth + 1):
        b = binomialCoefficient(boardDepth, bucket)
        p = probabilityForBucket(b, totalPaths)
       
        printData(boardDepth, totalPaths, bucket, b, p)
        
        # add to the list of data    
        data.append(b)
 
    return data
    
def createPlot(data):
    """data is a list.
       This method will convert Adthe list to a dictionary and pass it
       to a function to create a plot.
    """
    dataDict = {}

    # the dictionary needs to be zero based as the index is the bucket number
    for i in range(len(data)):
        dataDict[i]= data[i]
        
    plotResults(dataDict)

    return
    
    
# Client side code
def main(boardDepth = 30):
    totalPaths = 2 ** boardDepth
    
    createPlot(generateData(boardDepth, totalPaths))
    
    return
    
# main method
if __name__ == '__main__':
    main(boardDepth = 10)
# Out:
# **** Galton Board Output for Depth 10 ****
# **** Possible Paths 1024
# Bucket, Possible Paths, Probability Frac, Probability
#      0,              1,         1/1024,0.000977
#      1,             10,        10/1024,0.009766
#      2,             45,        45/1024,0.043945
#      3,            120,       120/1024,0.117188
#      4,            210,       210/1024,0.205078
#      5,            252,       252/1024,0.246094
#      6,            210,       210/1024,0.205078
#      7,            120,       120/1024,0.117188
#      8,             45,        45/1024,0.043945
#      9,             10,        10/1024,0.009766
#     10,              1,         1/1024,0.000977

# %% [markdown]
# #### Derive the Mean and the Variance

# %% [markdown]
# It is common to ask what the average is of a distribution. The purpose of this section is to derive the mean (the fancy was to say average in mathematese) and the variance.  The variance represents the "spread" of the distribution from the mean.

# %% [markdown]
# ##### Deriving the Binomial Distribution Mean

# %% [markdown]
# The mean of a distribution is defined by
#
# \begin{equation}
# \begin{split}
# E(x) = \mu = \sum_{x=0}^{n} x P(x)
# \end{split}
# \label{eq:binomial1-4} \tag{1-4}
# \end{equation}
#
# where E(x) is the "expectation" value of x given n number of trials each with a probability of P(x).
#
# The Binomial Theorem states that we can expand a binomial as follows:
# \begin{equation}
# \begin{split}
# (a + b)^n &= \sum_{x=0}^{n} \binom{n}{x} a^x b^{n - x} \\
# &= \sum_{x=0}^{n} \frac{n!}{x! \cdot (n - x)!}  a^x b^{n - x}
# \end{split}
# \label{eq:binomial1-5} \tag{1-5}
# \end{equation}
#
# For example, if we want to expand $(a + b)^3$ using the sum of the terms with Binomial coefficients, the result is:
# \begin{equation}
# \begin{split}
# (a + b)^3 &= \sum_{x=0}^{3} \binom{3}{x} a^x b^{3 - x} \\
# &= \frac{3!}{ \underbrace{0!}_{\text{= 1}} \cdot (3 - 0)!} a^0 b^{3-0} + \frac{3!}{1! \cdot (3 - 1)!} a^1 b^{3-1} + \frac{3!}{2! \cdot (3 - 2)!} a^2 b^{3-2} + \frac{3!}{3! \cdot \underbrace{(3 - 3)!}_{\text{= 1}} } a^3 b^{3-3} \\
# &= b^3 + 3 a b^2 + 3 a^2 b + a^3 \\
# &= a^3 + 3 a b^2 + 3 a^2 b + b^3
# \end{split}
# \label{eq:binomial1-6} \tag{1-6}
# \end{equation}
#
# To calculate the mean
# \begin{equation}
# \begin{split}
# E(x) &= \sum_{x=0}^{N} x P(x) \\
# &= \sum_{x = 0}^{N} \underbrace{x \cdot \frac{n!}{x! \cdot (n - x)!}  p^x (1 - p)^{n - x}}_{\text{=0 when x = 0}} \\
# &= \sum_{x = 1}^{N} x \cdot \frac{n!}{x! \cdot (n - x)!}  p^x (1 - p)^{n - x} \\
# &= \sum_{x = 1}^{N} \frac{n!}{(x - 1)! \cdot (n - x)!}  p^x (1 - p)^{n - x} \\
# &= n \sum_{x = 1}^{N} \frac{(n - 1)!}{(x - 1)! \cdot (n - x)!}  p^x (1 - p)^{n - x} \\
# &= np \sum_{x = 1}^{N} \frac{(n - 1)!}{(x - 1)! \cdot \underbrace{(n - x)}_{=(n - 1) - (x - 1)}!}  (1 - p)^{x - 1} p^{n - x} \\
# &= np \sum_{x = 1}^{N} \frac{(n - 1)!}{(x - 1)! \cdot [(n - 1) - (x - 1)]!}  p^{x - 1} (1 - p)^{(n - 1) - (x - 1)}
# \end{split}
# \label{eq:binomial1-7} \tag{1-7}
# \end{equation}
#
# let $m = n - 1$ and $y = x - 1$
# \begin{equation}
# \begin{split}
# &=np \sum_{y = 0}^{m} \frac{m!}{y! \cdot (m - y)!}  p^{y} (1 - p)^{(m - y)}    \\
# &=np \underbrace{\sum_{y = 0}^{m} \binom{m}{y}  p^{y} (1 - p)^{(m - y)}}_{= (a + b)^m}
# \end{split}
# \label{eq:binomial1-8} \tag{1-8}
# \end{equation}
#
# Substitute $a = p$ and $b = 1 - p$
# \begin{equation}
# \begin{split}
# &= np \cdot (p + (1 - p) )^m \\
# &= np \cdot 1^m \\
# &= np
# \end{split}
# \label{eq:binomial1-9} \tag{1-9}
# \end{equation}

# %% [markdown]
# ##### Deriving the Binomial Distribution Variance

# %% [markdown]
# The variance of a distribution is the difference between x and the mean of the distribution.  It is defined by
# \begin{equation}
# \begin{split}
# var(x) &= [(x - \mu)^2] \\
# &= E(x^2) - [\underbrace{E(x)}_{\text{= np}}]^2
# \end{split}
# \label{eq:binomial1-10} \tag{1-10}
# \end{equation}
#
# Need to find $E(x^2)$.
# \begin{equation}
# \begin{split}
# E(x^2) &= \sum_{x=0}^{N} x^2 P(x)
# \end{split}
# \label{eq:binomial1-11} \tag{1-11}
# \end{equation}
#
# The trick to this is to calculate $E[(x(x-1)] = E(x^2 - x) = E(x^2) - E(x)$.
# \begin{equation}
# \begin{split}
# E(x^2 - x) &= \sum_{x=0}^{N} x^2 P(x) \\
# &= \sum_{x = 0}^{N} \underbrace{x(x-1) \cdot \frac{n!}{x! \cdot (n - x)!}  p^x (1 - p)^{n - x}}_{\text{=0 when x = 0 and x = 1}} \\
# &= \sum_{x = 2}^{N} x(x-1) \cdot \frac{n!}{x \cdot (x - 1) \cdot (x - 2)! \cdot (n - x)!}  p^x (1 - p)^{n - x} \\
# &= \sum_{x = 2}^{N} \cdot \frac{n!}{(x - 2)! \cdot (n - x)!}  p^x (1 - p)^{n - x}
# \end{split}
# \label{eq:binomial1-12} \tag{1-12}
# \end{equation}
#
# Since the sum starts with an index of 2, certain terms will be pulled out.
# \begin{equation}
# \begin{split}
# &= n \cdot (n - 1) \sum_{x = 2}^{N} \cdot \frac{(n - 2)!}{(x - 2)! \cdot (n - x)!}  p^x (1 - p)^{n - x} \\
# &= n \cdot (n - 1) \cdot p^2 \sum_{x = 2}^{N} \cdot \frac{(n - 2)!}{(x - 2)! \cdot \underbrace{(n - x)}_{= (n - 1) - (x - 1)}!}  p^{x - 2} (1 - p)^{n - x} \\
# &= n \cdot (n - 1) \cdot p^2 \sum_{x = 2}^{N} \cdot \frac{(n - 2)!}{(x - 2)! \cdot [(n - 1) - (x - 1)]!}  p^{x - 2} (1 - p)^{[(n - 1) - (x - 1)]}
# \end{split}
# \label{eq:binomial1-13} \tag{1-13}
# \end{equation}
#
# Let $m = n - 2$ and $y = x - 2$
# \begin{equation}
# \begin{split}
# &= n \cdot (n - 1) \cdot p^2 \sum_{y=0}^{m} \cdot \frac{m!}{y! \cdot (m - y)!}  p^{y} (1 - p)^{m - y} \\
# &= n \cdot (n - 1) \cdot p^2 \underbrace{\sum_{y = 0}^{m} \binom{m}{y}  p^{y} (1 - p)^{(m - y)}}_{= (a + b)^m}
# \end{split}
# \label{eq:binomial1-14} \tag{1-14}
# \end{equation}
#
# Substitute $a = p$ and $b = 1 - p$
# \begin{equation}
# \begin{split}
# &= n(n-1)p^2 \cdot (p + (1 - p) )^m \\
# &= n(n-1)p^2 \cdot 1^m \\
# &= n(n-1)p^2
# \end{split}
# \label{eq:binomial1-15} \tag{1-15}
# \end{equation}
#
# \begin{equation}
# \begin{split}
# E(x^2 - x) &= E(x^2) - E(x) \\
# &= E(x^2) - np =  n(n-1)p^2
# \end{split}
# \label{eq:binomial1-16} \tag{1-16}
# \end{equation}
#
# Therefore,
# \begin{equation}
# \begin{split}
# E(x^2) =  n(n-1)p^2 + np
# \end{split}
# \label{eq:binomial1-17} \tag{1-17}
# \end{equation}
#
# and the variance is then
# \begin{equation}
# \begin{split}
# var(x) &=  E(x^2) - [E(x)]^2 \\
# &= n(n-1)p^2 + np - (np)^2 \\
# &= (np)^2 - np^2 + np - (np)^2 \\
# &= np - np^2 \\
# &= np (1 - p)
# \end{split}
# \label{eq:binomial1-18} \tag{1-18}
# \end{equation}

# %% [markdown]
# ### Poisson Distribution

# %% [markdown]
# The Binomial Distribution defines how to calculate the probability of reaching a certain endpoint which there are k ways to randomly traverse a path of n layers.  What happens when there are hundreds or thousands of random paths to traverse in a board that is a million, or even a billion layers deep?  How do we calculate the coefficients of each bucket when 1,000,000! is a huge number?  Is this practical?
#
# It turns out as the depth of the board (number of layers to traverse) approaches a large number, and the probability of reaching any of the endpoints becomes really small, we can approximate the result of the Binomial Distribution with the values calculated from another distribution called the Poisson Distribution.
#
# Let's work through this.
#
# Let np be a constant ($\lambda$).  The Binomial Distribution can then be written as
# \begin{equation}
# \begin{split}
# P &= \binom{n}{k} \cdot p^k \cdot (1 - p)^{n-k}
# &= \binom{n}{x} \cdot (\frac{\lambda}{n})^x \cdot (1 - \frac{\lambda}{n})^{n-x}
# \end{split}
# \label{eq:binomial1-19} \tag{1-19}
# \end{equation}
#
# The following derivation ensues:
# \begin{equation}
# \begin{split}
# P &= \frac{n!}{x! \cdot (n - x)!} \cdot (\frac{\lambda}{n})^x \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda}{n})^x \cdot \frac{n!}{x! \cdot (n - x)!}  \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{n^x}) \cdot \frac{n!}{x! \cdot (n - x)!}  \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \underbrace{\cdot \frac{n!}{n^x \cdot (n - x)!}}_{= \frac{n \cdot (n-1) \cdot (n-2) \cdot (n-x+1) \cdot (n-x) \cdot (n-x-1) \cdot (n-x-2) \cdots 2 \cdot 1}{(n-x)! \cdot n \cdot n \cdot n \cdot \cdots n \cdot}}  \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \frac{n(n-1)(n-2)\cdots(n-x+1)(n-x)!}{(n-x)!n^x} \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \underbrace{\frac{n(n-1)(n-2)\cdots(n-x+1)}{n^x}}_{\text{x terms in numerator and denominator.}} \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \left[\frac{n}{n} \cdot \frac{(n-1)}{n} \cdot \frac{(n-2)}{n} \cdots \frac{(n-x+1)}{n} \right] \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \left[1 \cdot (1 - \frac{1}{n}) \cdot (1 - \frac{2}{n}) \cdots (1 - \frac{x-1}{n}) \right] \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \underbrace{\left[1 \cdot (1 - \frac{1}{n}) \cdot (1 - \frac{2}{n}) \cdots (1 - \frac{x-1}{n}) \right]}_{\text{as n $\rightarrow \infty$ each term $\rightarrow$ 1}} \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \cdot (1 - \frac{\lambda}{n})^{n - x}  \\
# &= (\frac{\lambda^x}{x!}) \cdot (1 - \frac{\lambda}{n})^n \cdot (1 - \frac{\lambda}{n})^{-x}   \\
# &= (\frac{\lambda^x}{x!}) \cdot \underbrace{(1 - \frac{\lambda}{n})^{n}}_{\text{recall $e^x = \lim_{n \to \infty}(1 + \frac{x}{n})^n$}}  \cdot (1 - \frac{\lambda}{n})^{-x}    \\
# &= (\frac{\lambda^x}{x!}) e^{- \lambda} \cdot \underbrace{(1 - \frac{\lambda}{n})^{-x}}_{\text{as n $\rightarrow \infty$ this term $\rightarrow$ 1}}  \\
# &= (\frac{\lambda^x}{x!}) e^{- \lambda}
# \end{split}
# \label{eq:binomial1-20} \tag{1-20}
# \end{equation}

# %% [markdown]
# ### Gaussian Distribution

# %% [markdown]
# In the example in Section 3, the user can vary the depth of the Galton Board.  As the depth of the board increases, the histogram transforms into a well-known distribution:  the Normal Distribution.  The mean is equal to the median and mode at the center of the plot.
#
# How does the Binomial Distribution which governs the expectation of how many times an endpoint (e.g. bucket) will be reached, relate to the well-known distribution curve that is observed for large n?  We saw that as np = $\lambda \rightarrow \infty$, the Binomial Distribution can be approximated by the Poisson Distribution.
#
# Let's see what happens when n $\rightarrow \infty$ and the number of possible paths leading to a specific endpoint $\rightarrow \infty$.  We will start with the Poisson probability density function.  Additionally, for large x, x! can be approximated by the Sterling approximation
#
# \begin{equation}
# \begin{split}
# x! \approx \sqrt{2 \pi} \cdot e^{-x} \cdot x^{x + \frac{1}{2}}
# \end{split}
# \label{eq:binomial1-21} \tag{1-21}
# \end{equation}
#
# Starting with the Poisson pdf,
# \begin{equation}
# \begin{split}
# P(x) &= (\frac{\lambda^x}{x!}) \cdot e^{- \lambda} \\
# &= (\frac{\lambda^x}{\sqrt{2 \pi} \cdot e^{-x} \cdot x^{x + \frac{1}{2}}}) e^{- \lambda} \\
# &= \frac{1}{\sqrt{2 \pi}} \cdot \frac{\lambda^x \cdot e^{-\lambda} \cdot e^{x}}{ x^{x + \frac{1}{2}}}  \\
# &= \frac{1}{\sqrt{2 \pi}} \cdot \frac{\lambda^x \cdot e^{-\lambda} \cdot e^{x}}{x^{x + \frac{1}{2}}} \cdot \frac{\sqrt{\lambda}}{\sqrt{\lambda}}  \\
# &= \frac{1}{\sqrt{2 \pi \lambda}} \cdot \frac{\lambda^{x + \frac{1}{2}} \cdot e^{-(\lambda - x)}}{x^{x + \frac{1}{2}}} \\
# \end{split}
# \label{eq:binomial1-22} \tag{1-22}
# \end{equation}
#
# The following steps will focus on the following term that will be set to B:
# \begin{equation}
# \begin{split}
# B  &= \frac{\lambda^{x + \frac{1}{2}} \cdot e^{-(\lambda - x)}}{x^{x + \frac{1}{2}}} \\
# &= \lim_{\lambda \rightarrow \infty \\ x \rightarrow \infty} \frac{\lambda^{x + \frac{1}{2}} \cdot e^{-(\lambda - x)}}{x^{x + \frac{1}{2}}} = \lim_{\lambda \rightarrow \infty \\ x \rightarrow \infty} (\frac{\lambda}{x})^{x + \frac{1}{2}} \cdot e^{-(\lambda - x)}
# \end{split}
# \label{eq:binomial1-23} \tag{1-23}
# \end{equation}
#
# Let's create a variable Z, which represents the number of standard deviations from the mean x is, and is mathematically defined as:
# \begin{equation}
# \begin{split}
# Z &= \frac{x - \lambda}{\sqrt \lambda} \\
# x &= Z \sqrt{\lambda} + \lambda \\
# \frac{x}{\lambda} &= 1 + \frac{Z}{\sqrt{\lambda}} \\
# \frac{\lambda}{x} &= (1 + \frac{Z}{\sqrt{\lambda}})^{-1}
# \end{split}
# \label{eq:binomial1-24} \tag{1-24}
# \end{equation}
#
# Recall, that the mean, $\mu = \lambda = np = E(x) $.  Making the substitutions
# \begin{equation}
# \begin{split}
# e^{-(\lambda - x)} = e^{x - \lambda} = e^{Z \sqrt{\lambda}} \\
# \end{split}
# \label{eq:binomial1-25a} \tag{1-25a}
# \end{equation}
# and
# \begin{equation}
# \begin{split}
# (\frac{\lambda}{x})^{x + \frac{1}{2}} = (1 + \frac{Z}{\sqrt{\lambda}})^{-1 \cdot (Z \sqrt{\lambda} + \lambda + \frac{1}{2})} = (1 + \frac{Z}{\sqrt{\lambda}})^{-(Z \sqrt{\lambda} + \lambda + \frac{1}{2})}
# \end{split}
# \label{eq:binomial1-25b} \tag{1-25b}
# \end{equation}
#
# Therefore
# \begin{equation}
# \begin{split}
# B &= e^{Z \sqrt{\lambda}} \cdot (1 + \frac{Z}{\sqrt{\lambda}})^{-(Z \sqrt{\lambda} + \lambda + \frac{1}{2})} \\
# ln(B) &= ln\left[e^{Z \sqrt{\lambda}} \cdot (1 + \frac{Z}{\sqrt{\lambda}})^{-(Z \sqrt{\lambda} + \lambda + \frac{1}{2})})\right] \\
# &= Z \sqrt{\lambda} -(Z \sqrt{\lambda} + \lambda + \frac{1}{2}) \cdot ln(1 + \frac{Z}{\sqrt{\lambda}})
# \end{split}
# \label{eq:binomial1-26} \tag{1-26}
# \end{equation}
#
# The $ln$ term can be expanded using the Taylor series approach,
# \begin{equation}
# \begin{split}
# f(y) &= f(y_0) + y f'(y_0) + \frac{y^2}{2!} f''(y_0) + \frac{y^3}{3!} f'''(y_0) \cdots \\
# ln (1 + y) &= ln(1 + y_0) + y \frac{1}{(1 + y_0)} + \frac{-y^2}{2! \cdot (1 + y_0)^2} + \frac{-1 \cdot -2 \cdot y^3}{3! \cdot (1 + y_0)^3} \cdots
# \end{split}
# \label{eq:binomial1-27} \tag{1-27}
# \end{equation}
#
# The approximation is taken around $y_{0} = 0$, so
# \begin{equation}
# \begin{split}
# &= ln(1) + y \frac{1}{(1)} + \frac{-y^2}{2! \cdot (1)^2} + \frac{-1 \cdot -2 \cdot y^3}{3! \cdot (1)^3} \cdots \\
# &= 0 + y - \frac{y^2}{2} + \frac{y^3}{3} \cdots \\
# &= y - \frac{y^2}{2} + \frac{y^3}{3} \cdots
# \end{split}
# \label{eq:binomial1-28} \tag{1-28}
# \end{equation}
#
# Substituting for y = $\frac{Z}{\sqrt \lambda}$
# \begin{equation}
# \begin{split}
# ln(B) &= Z \sqrt{\lambda} -(Z \sqrt{\lambda} + \lambda + \frac{1}{2}) \cdot ln(1 + \frac{Z}{\sqrt{\lambda}}) \\
# &= Z \sqrt{\lambda} -(Z \sqrt{\lambda} + \lambda + \frac{1}{2}) \cdot \left[\frac{Z}{\sqrt \lambda} - \frac{(\frac{Z}{\sqrt \lambda})^2}{2} + \frac{(\frac{Z}{\sqrt \lambda})^3}{3} \cdots \right] \\
# &= Z \sqrt{\lambda} -(Z \sqrt{\lambda} + \lambda + \frac{1}{2}) \cdot \left[\frac{Z}{\sqrt \lambda} - \frac{Z^2}{2 \lambda} + \frac{1}{3}(\frac{Z^3}{\lambda^{\frac{3}{2}}}) + \cdots \right] \\
# &= Z \sqrt{\lambda} - \left(Z^2 -\frac{Z^3}{2 \sqrt \lambda} \cdots + Z \sqrt \lambda - \frac{Z^2}{2} + \cdots + \frac{Z}{2 \sqrt \lambda} - \frac{Z^2}{4 \sqrt \lambda} + \cdots\right)\\
# &= - Z^2 + \frac{Z^3}{2 \sqrt \lambda} \cdots + \frac{Z^2}{2} - \cdots - \frac{Z}{2 \sqrt \lambda} + \frac{Z^2}{4 \sqrt \lambda} - \cdots \\
# &= - \frac{Z^2}{2} - \frac{Z}{2 \sqrt \lambda} + \frac{Z^2}{4 \sqrt \lambda} + \frac{Z^3}{2 \sqrt \lambda} - \cdots
# \end{split}
# \label{eq:binomial1-29} \tag{1-29}
# \end{equation}
#
# Taking the limit of $\lambda \rightarrow \infty$,
# \begin{equation}
# \begin{split}
# \lim_{\lambda \rightarrow \infty} ln(B) &= \lim_{\lambda \rightarrow \infty} \left[ - \frac{Z^2}{2} - \frac{Z}{2 \sqrt \lambda} + \frac{Z^2}{4 \sqrt \lambda} + \frac{Z^3}{2 \sqrt \lambda} - \cdots \right ]\\
#  &= \lim_{\lambda \rightarrow \infty} \left [- \frac{Z^2}{2}  - \underbrace{\frac{Z}{2 \sqrt \lambda}}_{\lambda \rightarrow \infty \\ \rightarrow 0} + \underbrace{\frac{Z^2}{4 \sqrt \lambda}}_{\lambda \rightarrow \infty \\ \rightarrow 0} + \underbrace{\frac{Z^3}{2 \sqrt \lambda}}_{\lambda \rightarrow \infty \\ \rightarrow 0} - \cdots \right ] \\
#  &= - \frac{Z^2}{2}
# \end{split}
# \label{eq:binomial1-30} \tag{1-30}
# \end{equation}
#
# Therefore,
# \begin{equation}
# \begin{split}
# \lim_{\lambda \rightarrow \infty} ln(B) &= \lim_{\lambda \rightarrow \infty } ln \left[(\frac{\lambda}{x})^{x + \frac{1}{2}} \cdot e^{-(\lambda - x)} \right] \\
#  &= - \frac{Z^2}{2} \\
#  e^{ln(B)} &= e^{-\frac{Z^2}{2}} \\
#  B &= e^{-\frac{Z^2}{2}}
# \end{split}
# \label{eq:binomial1-31} \tag{1-31}
# \end{equation}
#
# Solving for $P(x)$ with B,
# \begin{equation}
# \begin{split}
# P(x) &= \frac{1}{\sqrt{2 \pi \lambda}} B \\
# &= \frac{1}{\sqrt{2 \pi \lambda}} e^{-\frac{Z^2}{2}} \\
# &= \frac{1}{\sqrt{2 \pi \lambda}} e^{-\frac{1}{2}(\frac{x-\lambda}{\sqrt{\lambda}})^2} \\
# &= \frac{1}{\sqrt{2 \pi} \sigma} e^{-\frac{1}{2}(\frac{x-\mu}{\sigma})^2} \\
# \end{split}
# \label{eq:binomial1-32} \tag{1-32}
# \end{equation}
#
# So, the final solution is
# \begin{equation}
# \begin{split}
# P(x) = \frac{1}{\sqrt{2 \pi} \sigma} e^{-\frac{1}{2}(\frac{x-\mu}{\sigma})^2}
# \end{split}
# \label{eq:binomial1-33} \tag{1-33}
# \end{equation}
# which is the Normal (or Guassian) distribution.
